# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ### 꼭 기억하세요 😊
# + **시간이 다소 소요되더라도** 스스로 생각해서 프로그래밍을 해야**`실력이 향상 됩니다.`**
# + 다양한 문제를 통해서 **`문제 해결`**능력을 향상 시켜봐요.
# + 여러 방식으로 **`같은 결과 값`**이 나오도록 프로그래밍 해보세요.
# + **문제 해결**에 너무 시간이 오래 걸리면 **`검색(구글링 등)`**을 통해서 해결해보세요.
# + **`온라인 Python IDE :`** https://www.programiz.com/python-programming/online-compiler/

# %% [markdown]
# ***
# ## 4. Sequence Type Indexing💻
#
# **- Sequence : 순서가 있는 데이터 자료 형태**
#
# ***
# #### **`연습예제`** 💻

# %% [markdown]
# `아래 리스트(List)에서` **`index 함수`** `를 포함한 다양한 방법으로` **`"Banana"`** `를 인덱싱(추출) 해보세요.` `출력 결과와 같아야 되요.`
#
#
# ```python
# # 직접 접근, index함수 사용 가능
# x = ['Orange', 'Cherry', 'Apple', 'Kiwi', 'Banana', 'Strawberry']
#
# 출력 결과 : Banana
# ```

# %% [markdown]
# #### **`코딩영역`**

# %%
# 코딩 영역
# 직접 접근, index함수 사용 가능
x = ['Orange', 'Cherry', 'Apple', 'Kiwi', 'Banana', 'Strawberry']

#출력 결과 : Banana

print(x[4])
print(x[-2])
# Out:
# Banana
# Banana

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # 시퀀스 자료형(데이터의 값이 연속적으로 이루어진 자료구조) : List, Tuple, Str, Range..
# # List 관련 함수는 중요!
# # cmp, len, max, min, list, append, count, extend, index, insert, pop, remove, reverse, sort..
# # index 함수 대소문자 구분
# # sort, sorted 함수 차이도 중요
# ```
# </div>
# </details>

# %% [markdown]
# #### `결과 & 보충설명`

# %%
x = ['Orange', 'Cherry', 'Apple', 'Kiwi', 'Banana', 'Strawberry' , 'Banana' , 'Orange', 'Cherry', 'Apple', 'Kiwi']


print('Banana' in x)
print(x[4])
print(x.index('Banana'))
print(x[x.index('Banana')])

print(x.index('Banana', 7, len(x)))

##print(x.index('Banana', 시작 index, 끝index)
# Out:
# True
# Banana
# 4
# Banana
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 9
#       6 print(x.index('Banana'))
#       7 print(x[x.index('Banana')])
# ----> 9 print(x.index('Banana', 7, len(x)))
#
# ValueError: 'Banana' is not in list

# %% [markdown]
# ***
