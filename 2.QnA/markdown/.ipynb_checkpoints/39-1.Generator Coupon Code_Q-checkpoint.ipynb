# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ### 꼭 기억하세요 😊
# + **시간이 다소 소요되더라도** 스스로 생각해서 프로그래밍을 해야**`실력이 향상 됩니다.`**
# + 다양한 문제를 통해서 **`문제 해결`**능력을 향상 시켜봐요.
# + 여러 방식으로 **`같은 결과 값`**이 나오도록 프로그래밍 해보세요.
# + **문제 해결**에 너무 시간이 오래 걸리면 **`검색(구글링 등)`**을 통해서 해결해보세요.
# + **`온라인 Python IDE :`** https://www.programiz.com/python-programming/online-compiler/

# %% [markdown]
# ***
# ## 39. Generator Coupon Code💻
# ***
# #### **`연습예제`** 💻

# %% [markdown]
# `주어진` **`문자열`** `에서` **`6자리`** `의` **`무작위의 코드`** `를 ` **`중복없이 5개`** `생성하세요.(리스트)` **`출력 결과를 확인하세요.`**
#
# ```python
#
# import random
#
# # 문자열 선언
# characters = "abcdefghijklmnopqrstuvwxyz01234567890ABCDEFGHIJKLMNOPQRSTUVWXYZ!@#$%^&*()?"
#
# # 출력 결과
# ['ihv)jW', 'KFGN@o', 'L?w0yv', 'Y4hJ$O', 'K*bypg']
#
# ```

# %% [markdown]
# #### **`코딩영역`**

# %%
# 코딩 영역
import random
from datetime import datetime

# 다양한 방식으로 프로그래밍 가능

# 중복 제거에 대한 고려
#1. seed 사용
#2. set() 사용
#3. 반복문 체크

#방법1

def generate_coupon_code(n):
    characters = "abcdefghijklmnopqrstuvwxyz01234567890ABCDEFGHIJKLMNOPQRSTUVWXYZ!@#$%^&*()?"

    code_list = []
    random.seed(None) #datetime.now()

    for i in range(0, n):
        chosen = random.sample(characters, 8)
        #print(chosen)

        code = "".join(chosen)
        
        #print(code)

        code_list.append(code)
    return code_list
    
print(generate_coupon_code(3))
# Out:
# ['!whV)s4n', 'yucD1!8R', 'oYR9$Ak&']

# %%
def generate_coupon_code(n, a):
    characters = "abcdefghijklmnopqrstuvwxyz01234567890ABCDEFGHIJKLMNOPQRSTUVWXYZ!@#$%^&*()?"

    code_list = []
    random.seed(None) #datetime.now()

    for i in range(0, n):
        chosen = random.sample(characters, a)
        #print(chosen)

        code = "".join(chosen)
        
        #print(code)

        code_list.append(code)
    return code_list
    
print(generate_coupon_code(5, 8))
# Out:
# ['p1H#7WO5', 'mYSKk?Hg', 'a?QrY9V^', 'bH3q&JIN', 'Mo!inj75']

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # 랜덤으로 숫자 문자를 조합 후 중복없이 처리하는 방법도 중요합니다.
# # 실행 시 시간복잡도도 생각하셔야 해요.
#
# # UTC 기준 시간대 표현은 timezone 내장 모듈을 사용합니다.
#
# # random.choice : 1개 생성
# # random.choices : 다수 생성(중복 없음) python 3.6+
# # random.sample : 다수 생성(중복 있음)
#
# # random.choice(seq)
# # random.choices(population, weights=None, *, cum_weights=None, k=1)
# # random.sample(population, k, *, counts=None)
#
# # 참고
# # https://docs.python.org/3/library/random.html
# ```
# </div>
# </details>

# %% [markdown]
# ***
